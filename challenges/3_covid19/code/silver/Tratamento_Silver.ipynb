# %% [markdown]
# # Importa bibliotecas

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# %% [markdown]
# # Cria uma SparkSession

# %%
spark = SparkSession.builder.master('local[*]').getOrCreate()

# %% [markdown]
# # Importa dados

# %%
path_covid = '/content/drive/MyDrive/Pós Tech/Tech Challenges/Tech Challenge 3/dados/data_pnad_covid_19/manual_raw/DADOS/ano=2020/mes=10/PNAD_COVID_102020.csv'
df_covid = spark.read.csv(path_covid, header=True, inferSchema=True)
print('df.columns :', df_covid.columns)
# Out:
# df.columns : ['Ano', 'UF', 'CAPITAL', 'RM_RIDE', 'V1008', 'V1012', 'V1013', 'V1016', 'Estrato', 'UPA', 'V1022', 'V1023', 'V1030', 'V1031', 'V1032', 'posest', 'A001', 'A001A', 'A001B1', 'A001B2', 'A001B3', 'A002', 'A003', 'A004', 'A005', 'A006', 'A007', 'A008', 'A009', 'B0011', 'B0012', 'B0013', 'B0014', 'B0015', 'B0016', 'B0017', 'B0018', 'B0019', 'B00110', 'B00111', 'B00112', 'B00113', 'B002', 'B0031', 'B0032', 'B0033', 'B0034', 'B0035', 'B0036', 'B0037', 'B0041', 'B0042', 'B0043', 'B0044', 'B0045', 'B0046', 'B005', 'B006', 'B007', 'B008', 'B009A', 'B009B', 'B009C', 'B009D', 'B009E', 'B009F', 'B0101', 'B0102', 'B0103', 'B0104', 'B0105', 'B0106', 'B011', 'C001', 'C002', 'C003', 'C004', 'C005', 'C0051', 'C0052', 'C0053', 'C006', 'C007', 'C007A', 'C007B', 'C007C', 'C007D', 'C007E', 'C007E1', 'C007E2', 'C007F', 'C008', 'C009', 'C009A', 'C010', 'C0101', 'C01011', 'C01012', 'C0102', 'C01021', 'C01022', 'C0103', 'C0104', 'C011A', 'C011A1', 'C011A11', 'C011A12', 'C011A2', 'C011A21', 'C011A22', 'C012', 'C013', 'C014', 'C015', 'C016', 'C017A', 'D0011', 'D0013', 'D0021', 'D0023', 'D0031', 'D0033', 'D0041', 'D0043', 'D0051', 'D0053', 'D0061', 'D0063', 'D0071', 'D0073', 'E001', 'E0021', 'E0022', 'E0023', 'E0024', 'F001', 'F0021', 'F0022', 'F002A1', 'F002A2', 'F002A3', 'F002A4', 'F002A5', 'F0061', 'F006']

# %%
path_dicionarios = '/content/drive/MyDrive/Pós Tech/Tech Challenges/Tech Challenge 3/workspace/gold/dicionario_valores.csv'
df_dicionario_valores = spark.read.csv(path_dicionarios, header=True, inferSchema=True)
df_dicionario_valores.show()
# Out:
# +------+----------+-------------------+
# |CODIGO|SUB_CODIGO|          DESCRICAO|
# +------+----------+-------------------+
# |    UF|        11|           Rondônia|
# |    UF|        12|               Acre|
# |    UF|        13|           Amazonas|
# |    UF|        14|            Roraima|
# |    UF|        15|               Pará|
# |    UF|        16|              Amapá|
# |    UF|        17|          Tocantins|
# |    UF|        21|           Maranhão|
# |    UF|        22|              Piauí|
# |    UF|        23|              Ceará|
# |    UF|        24|Rio Grande do Norte|
# |    UF|        25|            Paraíba|
# |    UF|        26|         Pernambuco|
# |    UF|        27|            Alagoas|
# |    UF|        28|            Sergipe|
# |    UF|        29|              Bahia|
# |    UF|        31|       Minas Gerais|
# |    UF|        32|     Espírito Santo|
# |    UF|        33|     Rio de Janeiro|
# |    UF|        35|          São Paulo|
# +------+----------+-------------------+
# only showing top 20 rows

# %% [markdown]
# # Junta a base Covid19 com o dicionário de códigos

# %%
df_covid_com_valores = df_covid

for column in df_covid.columns[1:]:
    # Cria dicionário de códigos/valores
    df_filtro = df_dicionario_valores.where(df_dicionario_valores['CODIGO'] == column)
    dict_from_df_filtro = df_filtro.select('SUB_CODIGO', 'DESCRICAO').rdd.collectAsMap()

    # Converte chaves para string
    dict_from_df_filtro = {str(k): str(v) for k, v in dict_from_df_filtro.items()}
    df_covid_com_valores = df_covid_com_valores.withColumn(column, col(column).cast('string'))

    # Substitui códigos da base pelos valores do dicionário
    df_covid_com_valores = df_covid_com_valores.replace(to_replace=dict_from_df_filtro, subset=[column])

df_covid_com_valores.show(10)
# Out:
# +----+--------+--------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-----+-------------+-------------+------+----+------+------+--------------------+----+--------------------+------+--------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------+----+----+----+----+----+-----+-----+-----+----+--------------------+-----+--------------------+--------------------+--------------------+-----+------+------+-----+----+----+-----+--------------------+-----------+------+------+-----+------+------+-----+-----+--------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+------------------+-----+-----+------+------+------+------+------+---------------+----+
# | Ano|      UF|             CAPITAL|RM_RIDE|V1008|V1012|V1013|V1016|Estrato|      UPA| V1022|  V1023| V1030|       V1031|       V1032|posest|A001|A001A|       A001B1|       A001B2|A001B3|A002|  A003|  A004|                A005|A006|                A007|  A008|                A009|B0011|B0012|B0013|B0014|B0015|B0016|B0017|B0018|B0019|B00110|B00111|B00112|B00113|B002|B0031|B0032|B0033|B0034|B0035|B0036|B0037|B0041|B0042|B0043|B0044|B0045|B0046|B005|B006|B007|B008|B009A|B009B|B009C|B009D|B009E|B009F|B0101|B0102|B0103|B0104|B0105|B0106|                B011|C001|C002|C003|C004|C005|C0051|C0052|C0053|C006|                C007|C007A|               C007B|               C007C|               C007D|C007E|C007E1|C007E2|C007F|C008|C009|C009A|                C010|      C0101|C01011|C01012|C0102|C01021|C01022|C0103|C0104|               C011A|     C011A1|C011A11|C011A12|C011A2|C011A21|C011A22|C012|C013|C014|C015|C016|C017A|D0011|D0013|D0021|D0023|D0031|D0033|D0041|D0043|D0051|D0053|D0061|D0063|D0071|D0073|         E001|E0021|E0022|E0023|E0024|              F001|F0021|F0022|F002A1|F002A2|F002A3|F002A4|F002A5|          F0061|F006|
# +----+--------+--------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-----+-------------+-------------+------+----+------+------+--------------------+----+--------------------+------+--------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------+----+----+----+----+----+-----+-----+-----+----+--------------------+-----+--------------------+--------------------+--------------------+-----+------+------+-----+----+----+-----+--------------------+-----------+------+------+-----+------+------+-----+-----+--------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+------------------+-----+-----+------+------+------+------+------+---------------+----+
# |2020|Rondônia|Município de Port...|   NULL|    1|    4|   10|    6|1110011|110015970|Urbana|Capital|152790|122.75397639| 143.7459631|  1114|   1|    1|            5|            8|  1984|  36| Homem| Parda|      Médio completo|NULL|                NULL|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL| Sim|Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Reduziu o contato...| Sim|NULL|NULL|NULL|NULL| NULL| NULL| NULL| Não|Empregado do seto...| NULL|Sim, tem carteira...|Outro técnico ou ...|                   6| NULL|  NULL|  NULL| NULL|  48|  48| NULL|Indica se o quesi...|Em dinheiro|     4|  1045| NULL|  NULL|  NULL| NULL| NULL|Indica se o quesi...|Em dinheiro|      4|   1045|  NULL|   NULL|   NULL| Sim|NULL|NULL|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim| 1200|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    1|    4|   10|    6|1110011|110015970|Urbana|Capital|150739|122.75397639|148.52050973|  1124|   2|    2|           18|            8|  1990|  30|Mulher| Parda|   Superior completo|NULL|                NULL|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Reduziu o contato...| Sim|NULL|NULL|NULL|NULL| NULL| NULL| NULL| Não|       Conta própria| NULL|                NULL|Técnico, profissi...|Saúde humana e as...| NULL|  NULL|  NULL| NULL|  36|  36|  Não|Indica se o quesi...|Em dinheiro|     4|  1045| NULL|  NULL|  NULL| NULL| NULL|Indica se o quesi...|Em dinheiro|      4|   1045|  NULL|   NULL|   NULL| Sim|NULL| Não|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim| 1200|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    1|    4|   10|    6|1110011|110015970|Urbana|Capital|144993|122.75397639|158.31081955|  1112|   3|    4|           25|           12|  2006|  13| Homem| Parda|Fundamental incom...| Sim|Sim, e realizou p...|5 dias|De 2 horas a meno...| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL| Sim|Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Ficou rigorosamen...|NULL|NULL|NULL|NULL|NULL| NULL| NULL| NULL|NULL|                NULL| NULL|                NULL|                NULL|                NULL| NULL|  NULL|  NULL| NULL|NULL|NULL| NULL|                NULL|       NULL|  NULL|  NULL| NULL|  NULL|  NULL| NULL| NULL|                NULL|       NULL|   NULL|   NULL|  NULL|   NULL|   NULL|NULL|NULL|NULL|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim| 1200|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    1|    4|   10|    6|1110011|110015970|Urbana|Capital|144993|122.75397639|158.31081955|  1112|   4|    4|           24|            8|  2009|  11| Homem| Parda|Fundamental incom...| Sim|Sim, e realizou p...|5 dias|De 2 horas a meno...| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL| Sim|Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Ficou rigorosamen...|NULL|NULL|NULL|NULL|NULL| NULL| NULL| NULL|NULL|                NULL| NULL|                NULL|                NULL|                NULL| NULL|  NULL|  NULL| NULL|NULL|NULL| NULL|                NULL|       NULL|  NULL|  NULL| NULL|  NULL|  NULL| NULL| NULL|                NULL|       NULL|   NULL|   NULL|  NULL|   NULL|   NULL|NULL|NULL|NULL|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim| 1200|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    2|    1|   10|    6|1110011|110015970|Urbana|Capital| 92130|122.75397639| 123.6186403|  1126|   1|    1|           18|            5|  1963|  57|Mulher|Branca|Fundamental incom...|NULL|                NULL|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Ficou em casa e s...| Não| Não|NULL|NULL|NULL| NULL| NULL| NULL|NULL|                NULL| NULL|                NULL|                NULL|                NULL| NULL|  NULL|  NULL| NULL|NULL|NULL| NULL|                NULL|       NULL|  NULL|  NULL| NULL|  NULL|  NULL| NULL| NULL|                NULL|       NULL|   NULL|   NULL|  NULL|   NULL|   NULL|NULL|NULL| Não| Não|   1|  Sim|  Não| NULL|  Não| NULL|  Não| NULL|  Sim| 1045|  Não| NULL|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    3|    2|   10|    6|1110011|110015970|Urbana|Capital| 92130|122.75397639| 123.6186403|  1126|   1|    1|           25|           12|  1961|  58|Mulher| Preta|       Sem instrução|NULL|                NULL|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Sim|  Sim|  Não|  Não|  Não|  Não|Ficou em casa e s...| Sim|NULL|NULL|NULL|NULL| NULL| NULL| NULL| Não|       Conta própria| NULL|                NULL|Artesão, costurei...|               Outro| NULL|  NULL|  NULL| NULL|  30|  30|  Não|Indica se o quesi...|Em dinheiro|     1|   200| NULL|  NULL|  NULL| NULL| NULL|Indica se o quesi...|Em dinheiro|      0|     85|  NULL|   NULL|   NULL| Sim|NULL| Não|NULL|NULL| NULL|  Sim| 1045|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    4|    4|   10|    6|1110011|110015970|Urbana|Capital|123486|122.75397639| 153.6989627|  1115|   1|    1|           18|            2|  1973|  47| Homem| Parda|Fundamental incom...|NULL|                NULL|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Reduziu o contato...| Sim|NULL|NULL|NULL|NULL| NULL| NULL| NULL| Não|       Conta própria| NULL|                NULL|Pedreiro, servent...|                   5| NULL|  NULL|  NULL| NULL|  40|  20|  Sim|Indica se o quesi...|Em dinheiro|     4|  1500| NULL|  NULL|  NULL| NULL| NULL|Indica se o quesi...|Em dinheiro|      2|    600|  NULL|   NULL|   NULL| Sim|NULL| Não|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim|  600|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    4|    4|   10|    6|1110011|110015970|Urbana|Capital|138815|122.75397639|147.65287526|  1122|   4|    5|Não informado|Não informado|  9999|  18|Mulher| Parda|Fundamental incom...| Não|                NULL|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Ficou em casa e s...| Não| Não|NULL|NULL|NULL| NULL| NULL| NULL|NULL|                NULL| NULL|                NULL|                NULL|                NULL| NULL|  NULL|  NULL| NULL|NULL|NULL| NULL|                NULL|       NULL|  NULL|  NULL| NULL|  NULL|  NULL| NULL| NULL|                NULL|       NULL|   NULL|   NULL|  NULL|   NULL|   NULL|NULL|NULL| Não| Não|   3|  Não|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim|  600|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    4|    4|   10|    6|1110011|110015970|Urbana|Capital|144993|122.75397639|158.31081955|  1112|   7|    5|Não informado|Não informado|  9999|  11| Homem| Parda|Fundamental incom...| Sim|Não, porque estav...|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Ficou rigorosamen...|NULL|NULL|NULL|NULL|NULL| NULL| NULL| NULL|NULL|                NULL| NULL|                NULL|                NULL|                NULL| NULL|  NULL|  NULL| NULL|NULL|NULL| NULL|                NULL|       NULL|  NULL|  NULL| NULL|  NULL|  NULL| NULL| NULL|                NULL|       NULL|   NULL|   NULL|  NULL|   NULL|   NULL|NULL|NULL|NULL|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim|  600|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# |2020|Rondônia|Município de Port...|   NULL|    4|    4|   10|    6|1110011|110015970|Urbana|Capital|134141|122.75397639|162.98275892|  1121|   9|    5|Não informado|Não informado|  9999|   9|Mulher| Parda|Fundamental incom...| Sim|Não, porque estav...|  NULL|                NULL| Não | Não | Não | Não | Não | Não | Não | Não | Não |  Não |  Não |  Não |  Não |NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL| NULL|NULL|NULL|Não |Não | NULL| NULL| NULL| NULL| NULL| NULL|  Não|  Não|  Não|  Não|  Não|  Não|Ficou rigorosamen...|NULL|NULL|NULL|NULL|NULL| NULL| NULL| NULL|NULL|                NULL| NULL|                NULL|                NULL|                NULL| NULL|  NULL|  NULL| NULL|NULL|NULL| NULL|                NULL|       NULL|  NULL|  NULL| NULL|  NULL|  NULL| NULL| NULL|                NULL|       NULL|   NULL|   NULL|  NULL|   NULL|   NULL|NULL|NULL|NULL|NULL|NULL| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Não| NULL|  Sim|  600|  Não| NULL|  Não| NULL|Não solicitou| NULL| NULL| NULL| NULL|Próprio - já pago | NULL| NULL|   Sim|   Sim|   Sim|  Não |   Sim|Pessoa moradora|   1|
# +----+--------+--------------------+-------+-----+-----+-----+-----+-------+---------+------+-------+------+------------+------------+------+----+-----+-------------+-------------+------+----+------+------+--------------------+----+--------------------+------+--------------------+-----+-----+-----+-----+-----+-----+-----+-----+-----+------+------+------+------+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+--------------------+----+----+----+----+----+-----+-----+-----+----+--------------------+-----+--------------------+--------------------+--------------------+-----+------+------+-----+----+----+-----+--------------------+-----------+------+------+-----+------+------+-----+-----+--------------------+-----------+-------+-------+------+-------+-------+----+----+----+----+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-------------+-----+-----+-----+-----+------------------+-----+-----+------+------+------+------+------+---------------+----+
# only showing top 10 rows

# %% [markdown]
# # Seleciona colunas necessárias

# %%
df_covid_com_valores.createOrReplaceTempView('df_covid_com_valores')

# %%
covid_tratado = spark.sql(
    '''
    SELECT
      A002 as idade,
      A003 as sexo,
      A004 as cor_raca,
      B0011 as febre,
      A005 as escolaridade,
      B00111 as perda_cheiro_sabor,
      B0012 as tosse,
      B0014 as dificuldade_respirar,
      B002 as foi_hospital,
      B009A as fez_swab,
      B011 as resultado_teste,
      B0019 as fadiga,
      B007 as plano_de_saude,
      B008 as fez_teste_covid,
      B009C as coleta_sangue_furo_dedo,
      B009E as coleta_sangue_veia,
      C007A as area_trabalho,
      C011A as remuneracao,
      C013 as trabalho_remoto,
      D0031 as bolsa_familia,
      A006 as frequenta_escola,
      B00112 as dor_muscular,
      B00113 as diarreia,
      B0016 as dor_peito,
      B0031 as ficou_em_casa,
      B0033 as tomou_remedio_conta_propria,
      B0035 as recebeu_visita_sus,
      B0042 as buscou_pronto_socorro_sus_upa,
      B005 as ficou_internado,
      B006 as foi_sedado,
      B0103 as tem_asma_bronquite,
      C007C as cargo_no_trabalho,
      C007E as qtd_empregados_no_trabalho,
      C010 as remuneracao_em_todos_trabalhos,
      C012 as trabalhou_no_local_de_costume,
      C014 as contribui_inss,
      CAPITAL as capital,
      F002A2 as tem_alcool_no_domicilio,
      F002A3 as tem_mascara_no_domicilio,
      UF as unidade_federativa,
      V1013 as mes_da_pesquisa,
      V1022 as situacao_domicilio,
      V1023 as tipo_area

    FROM df_covid_com_valores
    '''
)
covid_tratado.show()
# Out:
# +-----+------+--------+-----+--------------------+------------------+-----+--------------------+------------+--------+--------------------+------+--------------+---------------+-----------------------+------------------+-------------+--------------------+---------------+-------------+----------------+------------+--------+---------+-------------+---------------------------+------------------+-----------------------------+---------------+----------+------------------+--------------------+--------------------------+------------------------------+-----------------------------+--------------+--------------------+-----------------------+------------------------+------------------+---------------+------------------+---------+
# |idade|  sexo|cor_raca|febre|        escolaridade|perda_cheiro_sabor|tosse|dificuldade_respirar|foi_hospital|fez_swab|     resultado_teste|fadiga|plano_de_saude|fez_teste_covid|coleta_sangue_furo_dedo|coleta_sangue_veia|area_trabalho|         remuneracao|trabalho_remoto|bolsa_familia|frequenta_escola|dor_muscular|diarreia|dor_peito|ficou_em_casa|tomou_remedio_conta_propria|recebeu_visita_sus|buscou_pronto_socorro_sus_upa|ficou_internado|foi_sedado|tem_asma_bronquite|   cargo_no_trabalho|qtd_empregados_no_trabalho|remuneracao_em_todos_trabalhos|trabalhou_no_local_de_costume|contribui_inss|             capital|tem_alcool_no_domicilio|tem_mascara_no_domicilio|unidade_federativa|mes_da_pesquisa|situacao_domicilio|tipo_area|
# +-----+------+--------+-----+--------------------+------------------+-----+--------------------+------------+--------+--------------------+------+--------------+---------------+-----------------------+------------------+-------------+--------------------+---------------+-------------+----------------+------------+--------+---------+-------------+---------------------------+------------------+-----------------------------+---------------+----------+------------------+--------------------+--------------------------+------------------------------+-----------------------------+--------------+--------------------+-----------------------+------------------------+------------------+---------------+------------------+---------+
# |   36| Homem|   Parda| Não |      Médio completo|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |           Sim|           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Outro técnico ou ...|                      NULL|          Indica se o quesi...|                          Sim|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   30|Mulher|   Parda| Não |   Superior completo|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Técnico, profissi...|                      NULL|          Indica se o quesi...|                          Sim|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   13| Homem|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |           Sim|           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   11| Homem|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |           Sim|           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   57|Mulher|  Branca| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou em casa e s...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   58|Mulher|   Preta| Não |       Sem instrução|              Não | Não |                Não |        NULL|    NULL|Ficou em casa e s...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Artesão, costurei...|                      NULL|          Indica se o quesi...|                          Sim|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   47| Homem|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Pedreiro, servent...|                      NULL|          Indica se o quesi...|                          Sim|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   18|Mulher|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou em casa e s...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Não|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   11| Homem|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |    9|Mulher|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   10| Homem|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   26| Homem|   Parda| Não |      Médio completo|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|             Não|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Agricultor, criad...|                      NULL|          Indica se o quesi...|                          Sim|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   14| Homem| Amarela| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   15|Mulher|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou rigorosamen...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|             Sim|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   33|Mulher|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Ficou em casa e s...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   62| Homem|   Parda| Não |       Sem instrução|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Mecânico de veícu...|                      NULL|          Indica se o quesi...|                          Sim|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   62|Mulher|   Parda| Não |Fundamental incom...|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|                NULL|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                NULL|                      NULL|                          NULL|                         NULL|           Não|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   34| Homem|   Parda| Não |      Médio completo|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                   8|                      NULL|          Indica se o quesi...|                          Sim|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   26|Mulher|   Parda| Não | Superior incompleto|              Não | Não |                Não |        NULL|    NULL|Reduziu o contato...|  Não |          Não |           Não |                   NULL|              NULL|         NULL|Indica se o quesi...|           NULL|          Não|             Não|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|                   4|                      NULL|          Indica se o quesi...|                          Sim|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# |   44| Homem|   Parda| Não |   Superior completo|              Não | Não |                Não |        NULL|    Não |Reduziu o contato...|  Não |          Não |            Sim|                    Sim|               Sim|     Estadual|Indica se o quesi...|           NULL|          Não|            NULL|        Não |    Não |     Não |         NULL|                       NULL|              NULL|                         NULL|           NULL|      NULL|               Não|Outra profissão d...|                      NULL|          Indica se o quesi...|                          Sim|          NULL|Município de Port...|                    Sim|                     Sim|          Rondônia|             10|            Urbana|  Capital|
# +-----+------+--------+-----+--------------------+------------------+-----+--------------------+------------+--------+--------------------+------+--------------+---------------+-----------------------+------------------+-------------+--------------------+---------------+-------------+----------------+------------+--------+---------+-------------+---------------------------+------------------+-----------------------------+---------------+----------+------------------+--------------------+--------------------------+------------------------------+-----------------------------+--------------+--------------------+-----------------------+------------------------+------------------+---------------+------------------+---------+
# only showing top 20 rows

# %% [markdown]
# # Converte resultado para CSV

# %%
covid_tratado.write.mode('overwrite').option('header', 'true').csv('/content/drive/MyDrive/Pós Tech/Tech Challenges/Tech Challenge 3/workspace/gold/covid_gold.csv')

# %% [markdown]
# # Converte resultado para Parquet

# %%
covid_tratado.write.mode('overwrite').option('header', 'true').parquet('/content/drive/MyDrive/Pós Tech/Tech Challenges/Tech Challenge 3/gold/covid_gold.parquet')
